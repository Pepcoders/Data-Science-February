# %% [markdown]
# <a href="https://colab.research.google.com/github/Pepcoders/Data-Science-February/blob/main/Visualization/Matplotlit_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💡 **Matplotlib Tutorial for Beginners** 😎

# %% [markdown]
# ## 📖 **What you'll Learn in this Tutorial**
# 👉 Matplotlib Anatomy <br>
# 👉 Create a variety of charts, Bar Charts, Line Charts, Stacked Charts, Donut and Pie Charts, Histograms, KDE plots, Violinplots, Boxplots, Scatter Plots, Heatmaps..etc <br>
# 👉 Feel comfortable managing various Matplotlib Artists such as Legends, Annotations, Texts, Patches, Lines, Collections, Containers, Axis <br>

# %% [markdown]
# ## 👨‍🎓 **Who can Refer this Tutorial**
# ✔ Anyone who wants to gain granular control over Matplotlib Charts. <br>
# ✔ Anyone who wants to gain an intuition behind Matplotlib. <br>
# ✔ Anyone who wants to learn to make a variety of charts with Matplotlib. <br>

# %% [markdown]
# ## 📝 **Prerequisite**
# ✍ Beginner level knowledge of Python

# %% [markdown]
# ## 📚 **Table of Contents**
# I will update soon

# %% [markdown]
# ## **What is matplotlib?**
#
# "*Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. Matplotlib can be used in Python scripts, the Python and IPython shells, the Jupyter notebook, web application servers, and four graphical user interface toolkits*"
#
# - Matplotlib was created by **john hunter**. It was originally developed as an electrocorticography (ECoG) visualization tool.

# %% [markdown]
# ## **Architecture of matplotlib**
# The Matplotlib architecture is composed of three main layers:
#
# - **Scripting Layer** — The lightest scripting interface among the three layers, designed to make Matplotlib work like MATLAB script.
# - **Artist Layer** — Allows full control and fine-tuning of the Matplotlibfigure — the top-level container for all plot elements.
# - **Backend Layer** — Handles all the heavy works via communicating to the drawing toolkits in your machine. It is the most complex layer.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Back-end layer:**
# Back-end layer of matplotlib provides the implementations of three abstract interface classes.
# #### *1. FigureCanvas:*
# - Provides area onto which figure is drawn.
# - Example: for drawing in real world, we need paper onto which we can draw. FigureCanvas is similar to paper.
# > matplotlib.backend_bases.FigureCanvas
#
# #### *2. Renderer:*
# - It does drawing on FigureCanvas.Instance of Renderer knows how to draw on the FigureCanvas.
# - Example: just like we need paintbrush , pen or pencil to draw on paper , we use Renderer object to draw on FigureCanvas.
# > matplotlib.backend_bases.Renderer
#
# #### *3. Event:*
# - Instance of Event handles user input like keystrokes, mouse clicks.
# > matplotlib.backend_bases.Event
#
# ### **Artist layer:**
# - Artist layer comprised of one object known as Artist.
# - FigureCanvas from back-end layer is paper, artist object knows how to use Renderer object to draw on canvas.
# - Everything we see on matplotlib figure is an instance of Artist. Example: title,lines,labels,images etc.
#
# ### **Scripting layer:**
# - Artist layer is syntactically heavy for the everyday purposes, especially for exploratory work . Matplotlib provides lighter scripting interface to simplify common task .
# - Scripting layer composed mainly of pyplot, a lighter interface than Artist layer .
# > matplotlib.pyplot

# %% [markdown]
# ## **Install Matplotlib**

# %% [markdown]
# - We can use the python package manager pip or conda to install matplotlib.
# - Open the command prompt window, and type the following command:
# > pip install matplotlib
# - If you are using conda, use the following command:
# > conda install matplotlib
#
# **Verify the Installation**

# %%
import matplotlib  
matplotlib.__version__
# Out:
# '3.2.2'

# %% [markdown]
# ### Importing Matplotlib
# - Before we need to actually start using Matplotlib, we need to import it.
# - Most of the time, we have to work with pyplot interface of Matplotlib. So we will import Matplotlib as follows:-

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Basic Example of plotting Graph**
# - The `plot()` function is used to draw points in a figure.
# - By default, the `plot()` function draws a line from point to point.
# - Parameter 1 is an array containing the points on the **x-axis**.
# - Parameter 2 is an array containing the points on the **y-axis**.
# - The `show()` function is used to show the figure.

# %%
import matplotlib.pyplot as plt

x = [10, 20, 30]
y = [20, 40, 30]

plt.plot(x, y)
plt.show()

# %% [markdown]
# - If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3.

# %%
y = [10, 40, 20, 30]
plt.plot(y)
plt.show()

# %% [markdown]
# - We can call `help()` to know more about the `plot()`

# %%
help(plt.plot)

# %% [markdown]
# ### Markers
# - we can use the keyword argument **marker** to emphasize each point with a specified marker:
# <br>Examples:
#  - 'o' -> Circle
#  - '*' -> Star
#  - '.' -> Point
#  - 'x' -> X
#  - '+' -> Plus
#  - 'P' -> Plus (filled)
#  - '^' -> Triangle Up
#  - '_' -> Hline
#  <br>....etc
# - we can use the keyword argument **markersize** or the shorter version, **ms** to set the size of the markers
# - we can use the keyword argument **markeredgecolor** or the shorter **mec** to set the color of the edge of the markers
# - we can use the keyword argument **markerfacecolor** or the shorter **mfc** to set the color inside the edge of the markers
#
# #### **NOTE:** You can learn more about Marker, Line, LineStyle, Color..ect by running `help(plt.plot)`

# %%
plt.plot(y, marker = 'o', ms = 20, mec = 'red', mfc = 'orange')
plt.show()

# %% [markdown]
# ### Linestyle
# - We can use the keyword argument **linestyle**, or shorter **ls**, to change the style of the plotted line
#     - We can choose any of these styles
#         - 'solid'(default) or '-'
#         - 'dotted' or ':'
#         - 'dashed' or '--'
#         - 'dashdot' or '-.'
#         - 'None' or ''
# - We can use the keyword argument **color** or the shorter **c** to set the color of the line
# - we can use the keyword argument **linewidth** or the shorter **lw** to change the width of the line

# %%
plt.plot(y, ls = '--', c = 'orange', lw = '3')
plt.show()

# %% [markdown]
# ### Format Strings
# - we can use also use the shortcut string notation parameter to specify the marker.
# - This is also called `fmt`, and is written with this syntax:
# >marker | line | color

# %%
plt.plot(y, '^:r')
plt.show()

# %% [markdown]
# ### Labels & Grid
# - we can use the `xlabel()` and `ylabel()` functions to set a label for the x- and y-axis.
# - the `title()` function is used to set a title for the plot.
# - the `grid()` function is used to add grid lines to the plot.

# %%
x = [10, 11, 12, 13, 14]
y = [12, 14, 20, 22, 30]

plt.plot(x, y, marker = 'o')

plt.title("Temperature Data")
plt.xlabel("Time")
plt.ylabel("Temperature in cel")

plt.grid()

plt.show()

# %% [markdown]
# ## Anatomy of Plots
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
y = np.linspace(10, 30, 15)

plt.plot(y)
plt.plot(y**2.5)
plt.plot(y**3)
plt.show()

# %%
plt.figure()
plt.plot(y)
plt.figure()
plt.plot(y**2.5)
plt.figure()
plt.plot(y**3)
plt.show()

# %% [markdown]
# ### Figure Size

# %%
plt.figure(figsize=(12, 4))
plt.plot(y**3)

# %% [markdown]
# ### Stylesheets

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")
plt.plot(y)
plt.plot(y**2.5)
plt.plot(y**3)
plt.show()

# %% [markdown]
# ## Bar Charts
