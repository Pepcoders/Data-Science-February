# %% [markdown]
# <a href="https://colab.research.google.com/github/Pepcoders/Data-Science-Assignements/blob/main/DL%20_Intro/A_Single_Neuron_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Deep Learning**
#
# Deep Learning is a subfield of machine learning concerned with algorithms inspired by the structure and function of the brain called artificial neural networks.

# %% [markdown]
# #Linear Unit
#
# The fundamental component of a neural network: the individual neuron. As a diagram, a neuron (or unit) with one input looks like.
#
# ![mfOlDR6.png](data:image/png;base64,...)
#
# The Linear Unit Y = wx + b
#
# w = weights , b = bias
#
# The y is the value the neuron ultimately outputs. To get the output, the neuron sums up all the values it receives through its connections. This neuron's activation is y = w * x + b.

# %% [markdown]
# #Linear Model
#
# Single neuron models are linear models.
#
# let's calculate value of Y(output) for a single input.
#
# suppose a neaurons geting a input (x = 20), weights (w = 40) and bias(b = 3).
#
# Then the output of a liner unit neurons is (y = w*x + b). that is 803.
#
# ![Screenshot_20220408_125614.png](data:image/png;base64,...)

# %% [markdown]
# #Multiple Input
#
# Now suppose we have three inputs values. then how we will calculate output.
#
# To find the output, we would multiply each input to its connection weight and then add them all together.
#
#
#
# ![vyXSnlZ.png](data:image/png;base64,...)
#
# >>A Linear unit with three input
#
#
# The formula for this neuron would be  y = w0x0 + w1x1 + w2x2 + b.

# %% [markdown]
# #Linear Units Throus Keras
#
# The easiest way to create a model in Keras is through *keras.Sequential*, which creates a neural network as a stack of layers. We can create models like those above using a dense layer.

# %%
# import keras from tensorflow
from tensorflow import keras
# import layers
from tensorflow.keras import layers

# Create a network with 1 linear unit
model = keras.Sequential([
    layers.Dense(units=1, input_shape=[3])
])

# %% [markdown]
# #Linear Regression Using Linear Unit

# %%
# load dataset 
import pandas as pd 
import numpy as np 

data = pd.read_csv("https://raw.githubusercontent.com/Ramanand-Yadav/DataSet/main/red-wine.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# The label is quality of the wine.
#
# and all others parameters is featutre.
#
# so the task is You have to make a model using keras.

# %% [markdown]
# #1. Input Shape

# %%
# fill the value
input_shape = ??

# %% [markdown]
# #2. Define a linear model
#
# Now define a linear model appropriate for this task. Pay attention to how many inputs and outputs the model should have

# %%
# import keras 
from tensorflow import ??
# import layers
from tensorflow.keras import ??

# YOUR CODE HERE
model = keras.??([
    layers.Dense(??, ??)
])

# %% [markdown]
# #3. Look at the weights
#
# A model's weights are kept in its weights attribute as a list of tensors. Get the weights of the model you defined above.

# %%
# get weights
w, b = model.??

# %%
# weights and bias
print("Weights\n{}\n\nBias\n{}".format(w, b))

# %%
# Out:
# Weights
# <tf.Variable 'dense_1/kernel:0' shape=(11, 1) dtype=float32, numpy=
# array([[ 0.55248064],
#        [ 0.2045353 ],
#        [ 0.44445592],
#        [ 0.63429016],
#        [ 0.249538  ],
#        [ 0.4349603 ],
#        [-0.70183134],
#        [-0.48853117],
#        [-0.64419585],
#        [ 0.5236395 ],
#        [-0.54495114]], dtype=float32)>
#
# Bias
# <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>

# %%
# model summary
model.??

# %%
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 1)                 12
#
# ...
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split

Y = data['quality']
X = data.drop('quality', axis=1)
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size =0.2, random_state=0)

# %%
# compline the model use adam optimizer
model.compile(??='mse', optimizer=??)

# %%
# train the model use epochs=10
model.fit(??, ??, epochs=??)

# %%
# Out:
# Epoch 1/10
# 40/40 [==============================] - 1s 1ms/step - loss: 1385.4056
# Epoch 2/10
# 40/40 [==============================] - 0s 1ms/step - loss: 1126.4761
# Epoch 3/10
# 40/40 [==============================] - 0s 2ms/step - loss: 905.7462
# Epoch 4/10
# 40/40 [==============================] - 0s 2ms/step - loss: 723.7233
# Epoch 5/10
# 40/40 [==============================] - 0s 2ms/step - loss: 573.6261
# Epoch 6/10
# 40/40 [==============================] - 0s 2ms/step - loss: 452.4194
# Epoch 7/10
# 40/40 [==============================] - 0s 2ms/step - loss: 356.0018
# Epoch 8/10
# 40/40 [==============================] - 0s 2ms/step - loss: 280.0963
# Epoch 9/10
# 40/40 [==============================] - 0s 2ms/step - loss: 221.8049
# Epoch 10/10
# 40/40 [==============================] - 0s 2ms/step - loss: 177.5491

# %%
# make prediction
ynew = model.predict(??)

# %% [markdown]
# #**extra**

# %% [markdown]
# ##Ploting the output of an untrained linear model

# %%
# this cell is all about to set some parameter fro plotting 
# Setup plotting
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)

# %%
# run this cell many time and see what happens
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

model = keras.Sequential([
    layers.Dense(1, input_shape=[1]),
])

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

# print(x)
# print(y)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
w, b = model.weights # you could also use model.get_weights() here
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()
